# %% [markdown]
# ### Exploratory Data Analysis (EDA)
#
# This notebook focuses on understanding the e-commerce dataset before applying machine learning models.
# As Member 01, I performed initial data exploration by analyzing the structure, identifying data types, checking for missing values, and visualizing both numerical and categorical features.
#
# Key analyses include distribution of price and quantity, class distribution of delivery status and customer segments, and correlation between numerical variables. The insights obtained from this analysis help guide data preprocessing and model development in later stages of the project.

# %%
print("1_eda_and_preprocessing")

# %%
# Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# make plots look better
sns.set_style('whitegrid')

# %%
# Load the dataset
df = pd.read_csv('../data/ecommerce_data.csv')

# show first 5 rows
df.head()

# %%
# Basic Data Understanding

# shape of dataset
print("Shape:", df.shape)

# column names
print("Columns:", df.columns)

# data types and null values
df.info()

# statistical summary
df.describe()

# %%
# Check Missing Values

df.isnull().sum()

# %%
# Drop Unnecessary Columns

df = df.drop(columns=["order_id", "customer_id"], errors='ignore')

df.head()

# %%
# Convert Dates

# convert to datetime
df['order_date'] = pd.to_datetime(df['order_date'])
df['shipping_date'] = pd.to_datetime(df['shipping_date'])

# extract features
df['order_month'] = df['order_date'].dt.month
df['order_day'] = df['order_date'].dt.day

# shipping time (days)
df['shipping_time'] = (df['shipping_date'] - df['order_date']).dt.days

df.head()

# %%
# Numerical Data Analysis

# price distribution

plt.figure(figsize=(6,4))
sns.histplot(df['price'], bins=30, kde=True)
plt.title("Price Distribution")
plt.show()

# %%
# Quantity Distribution

plt.figure(figsize=(6,4))
sns.histplot(df['quantity'], bins=10, kde=True)
plt.title("Quantity Distribution")
plt.show()

# %%
# Categorical Data Analysis

# Delivery Status

plt.figure(figsize=(6,4))
sns.countplot(x='delivery_status', data=df)
plt.title("Delivery Status Distribution")
plt.show()

# %%
# Customer Segment

plt.figure(figsize=(6,4))
sns.countplot(x='customer_segment', data=df)
plt.title("Customer Segment Distribution")
plt.show()

# %%
# Payment Method

plt.figure(figsize=(6,4))
sns.countplot(x='payment_method', data=df)
plt.xticks(rotation=45)
plt.title("Payment Method Distribution")
plt.show()

# %%
# Correlation Analysis

plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
# Boxplot (Outliers)

plt.figure(figsize=(6,4))
sns.boxplot(x=df['price'])
plt.title("Price Outliers")
plt.show()

# %% [markdown]
# ### Key Findings:
#
# - Most orders are "Delivered" → class imbalance exists
# - Price is slightly right-skewed
# - VIP customers are fewer compared to others
# - Some outliers exist in price
# - Shipping time varies across orders

# %%
# Save Clean Dataset

df.to_csv("../data/cleaned_data.csv", index=False)

# %% [markdown]
# 3.1 Task: Exploratory Data Analysis (EDA) and Preprocessing Pipeline

# %%
# Check for Outliers in Quantity

plt.figure(figsize=(6,4))
sns.boxplot(x=df['quantity'])
plt.title("Quantity Outliers")
plt.show()

# %%
# Explore Relationships Between Features

# Price vs Quantity
plt.figure(figsize=(6,4))
sns.scatterplot(x='quantity', y='price', data=df)
plt.title("Price vs Quantity")
plt.show()

# Shipping time vs Price
plt.figure(figsize=(6,4))
sns.scatterplot(x='shipping_time', y='price', data=df)
plt.title("Shipping Time vs Price")
plt.show()

# %%
# Check Class Imbalance in Delivery Status

# Percentage of each class
delivery_counts = df['delivery_status'].value_counts(normalize=True) * 100
print(delivery_counts)

# %%
# Encode Categorical Features

# One-hot encode categorical columns
categorical_cols = ['customer_segment', 'payment_method', 'device_type', 'category', 'channel']

df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)
print(df_encoded.head())

# %% [markdown]
# ### Key EDA Insights
#
# - Most orders are "Delivered" → class imbalance exists.
# - VIP customers are fewer compared to others.
# - Price is slightly right-skewed, with some extreme outliers.
# - Quantity is mostly low; some outliers exist.
# - Shipping time varies across orders.
# - Certain payment methods and customer segments dominate.
# - Correlation analysis shows strong relationships between price and quantity.
# - Cleaned dataset saved as 'cleaned_data.csv' for modeling tasks.

# %%
# Ordinal (with order) → ordinal encoding

ordinal_cols = ['customer_segment']
segment_order = ['New', 'Returning', 'VIP']

# %%
# Step 2: Define numeric columns to scale

from sklearn.preprocessing import StandardScaler
numeric_cols = ['price', 'quantity', 'shipping_time', 'order_month', 'order_day']

# %%
# Create scaler
scaler = StandardScaler()

# %%
# Fit & transform the numeric columns
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

print(df[numeric_cols].head())

# %%
# Min–Max Normalization

from sklearn.preprocessing import MinMaxScaler

# Numeric columns
numeric_cols = ['price', 'quantity', 'shipping_time', 'order_month', 'order_day']

# Create scaler
minmax_scaler = MinMaxScaler()

# Fit & transform the numeric columns
df[numeric_cols] = minmax_scaler.fit_transform(df[numeric_cols])

print(df[numeric_cols].head())
